# %% [markdown]
# <a href="https://colab.research.google.com/github/SaidTheCoder/c140/blob/main/c138_140_Movie_Recomendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7fed7fb2-22e5-4a51-bd63-b7a552f53ed8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fed7fb2-22e5-4a51-bd63-b7a552f53ed8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# tmdb-movie-metadata.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# 'kaggle (1).json'   sample_data		    tmdb_5000_movies.csv
#  kaggle.json	    tmdb_5000_credits.csv   tmdb-movie-metadata.zip

# %%
# !unzip tmdb-movie-metadata.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
# replace tmdb_5000_credits.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: tmdb_5000_credits.csv
# replace tmdb_5000_movies.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: tmdb_5000_movies.csv

# %%
# !ls
# Out:
# 'kaggle (1).json'   sample_data		    tmdb_5000_movies.csv
#  kaggle.json	    tmdb_5000_credits.csv   tmdb-movie-metadata.zip

# %%
import pandas as pd
df1=pd.read_csv("tmdb_5000_movies.csv")
df1.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
df2=pd.read_csv("tmdb_5000_credits.csv")
df2.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
df2.columns=["id","title","cast","crew"]
df1=df1.merge(df2,on="id")
df1.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
#C139
C=df1["vote_average"].mean()
print(C)
# Out:
# 6.092171559442011

# %%
m=df1["vote_count"].quantile(0.9)
print(m)
# Out:
# 1838.4000000000015

# %%
q_movies=df1.copy().loc[df1["vote_count"]>=m]
print(q_movies.shape)
# Out:
# (481, 23)

# %%
def weighted_rating(x,m=m,C=C):
  v=x["vote_count"]
  R=x["vote_average"]
  return (v / (v + m)) *R + (m / (v + m)) *C  
q_movies["score"]=q_movies.apply(weighted_rating,axis=1)
q_movies=q_movies.sort_values("score",ascending=False)
q_movies[["original_title","vote_count","vote_average","score"]].head(10)
# Out:
#                                      original_title  ...     score
# 1881                       The Shawshank Redemption  ...  8.059258
# 662                                      Fight Club  ...  7.939256
# 65                                  The Dark Knight  ...  7.920020
# 3232                                   Pulp Fiction  ...  7.904645
# 96                                        Inception  ...  7.863239
# 3337                                  The Godfather  ...  7.851236
# 95                                     Interstellar  ...  7.809479
# 809                                    Forrest Gump  ...  7.803188
# 329   The Lord of the Rings: The Return of the King  ...  7.727243
# 1990                        The Empire Strikes Back  ...  7.697884
#
# [10 rows x 4 columns]

# %%
import plotly.express as px
fig=px.bar((q_movies.head(10).sort_values("score",ascending=False)),x="score",y="original_title",orientation="h")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7d8df2cf-26e1-4985-883c-f6c8e6c59bfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d8df2cf-26e1-4985-883c-f6c8e6c59bfd")) {
#                     Plotly.newPlot(
#                         '7d8df2cf-26e1-4985-883c-f6c8e6c59bfd',
# ...

# %%
#c140
df1[['original_title','cast','crew','keywords','genres']].head(10)
# Out:
#                              original_title  ...                                             genres
# 0                                    Avatar  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  Pirates of the Caribbean: At World's End  ...  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2                                   Spectre  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3                     The Dark Knight Rises  ...  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4                               John Carter  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5                              Spider-Man 3  ...  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6                                   Tangled  ...  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7                   Avengers: Age of Ultron  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
from ast import literal_eval
features=["cast","crew","keywords","genres"]
for feature in features:
  df1[feature]=df1[feature].apply(literal_eval)
df1.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title_x                  object
# vote_average            float64
# vote_count                int64
# title_y                  object
# cast                     object
# crew                     object
# dtype: object

# %%
import numpy as np

def get_director(x):
  for i in x:
    if i["job"]=="Director":
      return i["name"]
  return np.nan
df1["director"]=df1["crew"].apply(get_director)
df1.head(10)
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
# 5  258000000  ...          Sam Raimi
# 6  260000000  ...       Byron Howard
# 7  280000000  ...        Joss Whedon
# 8  250000000  ...        David Yates
# 9  250000000  ...        Zack Snyder
#
# [10 rows x 24 columns]

# %%
def get_list(x):
  if isinstance(x,list):
    names=[i['name'] for i in x] 
    return names
  return [ ]
features=["cast","keywords","genres"]
for feature in features:
  df1[feature]=df1[feature].apply(get_list)
df1.head()
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
df1[["original_title","cast","director","keywords","genres"]].head()
# Out:
#                              original_title  ...                                         genres
# 0                                    Avatar  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1  Pirates of the Caribbean: At World's End  ...                   [Adventure, Fantasy, Action]
# 2                                   Spectre  ...                     [Action, Adventure, Crime]
# 3                     The Dark Knight Rises  ...               [Action, Crime, Drama, Thriller]
# 4                               John Carter  ...           [Action, Adventure, Science Fiction]
#
# [5 rows x 5 columns]

# %%
def clean_data(x):
  if isinstance(x,list):
    return[str.lower(i.replace(" ","")) for i in x]
  else:
    if isinstance(x,str):
      return str.lower(x.replace(" ","")) 
    else:
      return ""
features=["cast","keywords","director","genres"]
for feature in features:
  df1[feature]=df1[feature].apply(clean_data)
df1.head()
# Out:
#       budget  ...          director
# 0  237000000  ...      jamescameron
# 1  300000000  ...     goreverbinski
# 2  245000000  ...         sammendes
# 3  250000000  ...  christophernolan
# 4  260000000  ...     andrewstanton
#
# [5 rows x 24 columns]

# %%
a=["hello","how","r","u",":D"]
"_".join(a)
# Out:
# 'hello_how_r_u_:D'

# %%
def create_soup(x):
  return " ".join(x["keywords"])+" ".join(x["cast"])+" ".join(x["director"])+" ".join(x["genres"])
df1["soup"]=df1.apply(create_soup,axis=1)
df1.head()
# Out:
#       budget  ...                                               soup
# 0  237000000  ...  cultureclash future spacewar spacecolony socie...
# 1  300000000  ...  ocean drugabuse exoticisland eastindiatradingc...
# 2  245000000  ...  spy basedonnovel secretagent sequel mi6 britis...
# 3  250000000  ...  dccomics crimefighter terrorist secretidentity...
# 4  260000000  ...  basedonnovel mars medallion spacetravel prince...
#
# [5 rows x 25 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
count=CountVectorizer(stop_words="english")
count_matrix=count.fit_transform(df1["soup"])
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim2=cosine_similarity(count_matrix,count_matrix)
df1=df1.reset_index()
indices=pd.Series(df1.index,index=df1["original_title"])

# %%
def get_recomendations(title,cosine_sim):
  idx=indices[title]
  sim_scores=list(enumerate(cosine_sim[idx]))
  sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
  sim_scores=sim_scores[1:11]
  movie_indices=[i[0]for i in sim_scores]
  return df1["original_title"].iloc[movie_indices]

# %%
get_recomendations("The Matrix",cosine_sim2)
# Out:
# 123                 The Matrix Revolutions
# 125                    The Matrix Reloaded
# 93      Terminator 3: Rise of the Machines
# 43                    Terminator Salvation
# 4032                          Sleep Dealer
# 1079                                  Dune
# 363           A.I. Artificial Intelligence
# 487                             Red Planet
# 1725                          Blade Runner
# 266                               I, Robot
# Name: original_title, dtype: object

# %%
get_recomendations("Interstellar",cosine_sim2)
# Out:
# 4332                    Silent Running
# 635                          Apollo 13
# 3405        Stargate: The Ark of Truth
# 3624                              Moon
# 643                      Space Cowboys
# 239                            Gravity
# 228                           Oblivion
# 335     Rise of the Planet of the Apes
# 2292     Thomas and the Magic Railroad
# 3043                  End of the Spear
# Name: original_title, dtype: object
